# %% [markdown]
# <a href="https://colab.research.google.com/github/guruirfan/gurumuhamadirfan/blob/main/lat5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = [70,60,65,100]
indeks = 0
for nil in nilai:
  print("Nilai ke", indeks, "=", nil)
  indeks = indeks + 1
# Out:
# Nilai ke 0 = 70
# Nilai ke 1 = 60
# Nilai ke 2 = 65
# Nilai ke 3 = 100
