# %% [markdown]
# <a href="https://colab.research.google.com/github/guruirfan/gurumuhamadirfan/blob/main/lat2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("4" + "7")
# Out:
# 47
