# %% [markdown]
# <a href="https://colab.research.google.com/github/guruirfan/gurumuhamadirfan/blob/main/lat3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#angka yang tidak diapit oleh tanda kutif dianggap sebagai integer
nilai1 = 10
nilai2 = 13
jumlah = nilai1 + nilai2
print(jumlah)
# Out:
# 23
