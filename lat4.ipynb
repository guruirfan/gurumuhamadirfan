# %% [markdown]
# <a href="https://colab.research.google.com/github/guruirfan/gurumuhamadirfan/blob/main/lat4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = [2,3,4,7]
print(nilai)
nilai[2]=8
print(nilai)
nilai.append(10)
print(nilai)
print(nilai[3])
# Out:
# [2, 3, 4, 7]
# [2, 3, 8, 7]
# [2, 3, 8, 7, 10]
# 7
